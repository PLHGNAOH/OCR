# %% [markdown]
# ## Import Libraries

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.250  Python-3.10.11 torch-2.9.1+cpu CPU (12th Gen Intel Core i5-12500H)
# Setup complete  (16 CPUs, 15.7 GB RAM, 21.2/260.7 GB disk)

# %%
#! pip install -q -U ultralytics
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#! pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
# Requirement already satisfied: scipy>=1.8.0 in d:\fpt_university\termno7\dat301m\ocr\ocr-venv\lib\site-packages (from scikit-learn) (1.15.3)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Requirement already satisfied: numpy>=1.22.0 in d:\fpt_university\termno7\dat301m\ocr\ocr-venv\lib\site-packages (from scikit-learn) (2.2.6)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import shutil
import xml.etree.ElementTree as ET

import yaml
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Extract Data from XML and Store in YOLO format

# %%
def extract_data_from_xml(path):
    tree = ET.parse(path)
    root = tree.getroot()

    image_paths = []
    image_sizes = []
    image_labels = []
    bounding_boxes = []

    for image in root:
        bbs_of_image = []
        labels_of_image = []

        for bbs in image.findall("taggedRectangles"):
            for bb in bbs:
                # check non-alphabet and non-number
                if not bb[0].text.isalnum():
                    continue

                if "é" in bb[0].text.lower() or "ñ" in bb[0].text.lower():
                    continue

                bbs_of_image.append(
                    [
                        float(bb.attrib["x"]),
                        float(bb.attrib["y"]),
                        float(bb.attrib["width"]),
                        float(bb.attrib["height"]),
                    ]
                )
                labels_of_image.append(bb[0].text.lower())

        # Store
        image_paths.append(image[0].text)
        image_sizes.append((int(image[1].attrib["x"]), int(image[1].attrib["y"])))
        bounding_boxes.append(bbs_of_image)
        image_labels.append(labels_of_image)

    return image_paths, image_sizes, image_labels, bounding_boxes

# %%
dataset_dir = "datasets/SceneTrialTrain"
words_xml_path = os.path.join(dataset_dir, "words.xml")
image_paths, image_sizes, image_labels, bounding_boxes = extract_data_from_xml(
    words_xml_path
)

# %%
print(f"Number of images: {len(image_paths)}")
print(f"Example image path: {image_paths[0]}")
print(f"Example image size: {image_sizes[0]}")
print(f"Example bounding boxes: {bounding_boxes[0][:2]}")
print(f"Example labels: {image_labels[0][:2]}")
# Out:
# Number of images: 250
# Example image path: apanar_06.08.2002/IMG_1261.JPG
# Example image size: (1600, 1200)
# Example bounding boxes: [[174.0, 392.0, 274.0, 195.0], [512.0, 391.0, 679.0, 183.0]]
# Example labels: ['self', 'adhesive']

# %% [markdown]
# ## 3. Convert to YOLO format

# %%
def convert_to_yolo_format(image_paths, image_sizes, bounding_boxes):
    yolo_data = []

    for image_path, image_size, bboxes in zip(image_paths, image_sizes, bounding_boxes):
        image_width, image_height = image_size

        yolo_labels = []

        for bbox in bboxes:
            x, y, w, h = bbox

            # Calculate normalized bounding box coordinates
            center_x = (x + w / 2) / image_width
            center_y = (y + h / 2) / image_height
            normalized_width = w / image_width
            normalized_height = h / image_height

            # Because we only have one class, we set class_id to 0
            class_id = 0

            # Convert to YOLO format
            yolo_label = f"{class_id} {center_x} {center_y} {normalized_width} {normalized_height}"
            yolo_labels.append(yolo_label)

        yolo_data.append((image_path, yolo_labels))

    return yolo_data

# %%
# Define class labels
class_labels = ["text"]

# Convert data into YOLO format
yolo_data = convert_to_yolo_format(image_paths, image_sizes, bounding_boxes)

# %% [markdown]
# ## 4. Train, val, test split

# %%
seed = 0
val_size = 0.2
test_size = 0.1
is_shuffle = True
train_data, test_data = train_test_split(
    yolo_data,
    test_size=val_size,
    random_state=seed,
    shuffle=is_shuffle,
)
test_data, val_data = train_test_split(
    test_data,
    test_size=test_size,
    random_state=seed,
    shuffle=is_shuffle,
)

# %% [markdown]
# ## 5. Save data

# %%
def save_data(data, src_img_dir, save_dir):
    # Create folder if not exists
    os.makedirs(save_dir, exist_ok=True)

    # Make images and labels folder
    os.makedirs(os.path.join(save_dir, "images"), exist_ok=True)
    os.makedirs(os.path.join(save_dir, "labels"), exist_ok=True)

    for image_path, yolo_labels in data:
        # Copy image to images folder
        shutil.copy(
            os.path.join(src_img_dir, image_path), os.path.join(save_dir, "images")
        )

        # Save labels to labels folder
        image_name = os.path.basename(image_path)
        image_name = os.path.splitext(image_name)[0]

        with open(os.path.join(save_dir, "labels", f"{image_name}.txt"), "w") as f:
            for label in yolo_labels:
                f.write(f"{label}\n")

# %%
save_yolo_data_dir = "datasets/yolo_data"
os.makedirs(save_yolo_data_dir, exist_ok=True)
save_train_dir = os.path.join(save_yolo_data_dir, "train")
save_val_dir = os.path.join(save_yolo_data_dir, "val")
save_test_dir = os.path.join(save_yolo_data_dir, "test")

save_data(train_data, dataset_dir, save_train_dir)
save_data(test_data, dataset_dir, save_val_dir)
save_data(val_data, dataset_dir, save_test_dir)

# %% [markdown]
# ## 6. Create yaml file

# %%
data_yaml = {
    "path": "./datasets/yolo_data",
    "train": "train/images",
    "test": "test/images",
    "val": "val/images",
    "nc": 1,
    "names": class_labels,
}

yolo_yaml_path = os.path.join(save_yolo_data_dir, "data.yml")
with open(yolo_yaml_path, "w") as f:
    yaml.dump(data_yaml, f, default_flow_style=False)

# %% [markdown]
# ## 7. Training

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train model
results = model.train(
    data=yolo_yaml_path,
    epochs=100,
    imgsz=640,
    cache=True,
    patience=20,
    plots=True,
)
# Out:
# Ultralytics 8.3.250  Python-3.10.11 torch-2.9.1+cpu CPU (12th Gen Intel Core i5-12500H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=datasets/yolo_data\data.yml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\FPT_university\termno7\DAT301m\OCR\runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 38.634.8 MB/s, size: 414.7 KB)
# train: Scanning D:\FPT_university\termno7\DAT301m\OCR\datasets\yolo_data\train\labels.cache... 200 images, 7 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200  0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.2GB RAM): 100% ━━━━━━━━━━━━ 200/200 528.4it/s 0.4s0.1s
# val: Fast image access  (ping: 0.10.0 ms, read: 5.02.8 MB/s, size: 76.7 KB)
# val: Scanning D:\FPT_university\termno7\DAT301m\OCR\datasets\yolo_data\val\labels.cache... 43 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 43/43 21.5Kit/s 0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.0GB RAM): 100% ━━━━━━━━━━━━ 43/43 575.2it/s 0.1s
# Plotting labels to D:\FPT_university\termno7\DAT301m\OCR\runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\FPT_university\termno7\DAT301m\OCR\runs\detect\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.634      3.098      1.446         59        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.7s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.3s
#                    all         43        200     0.0122      0.785      0.184     0.0806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      1.145      2.059      1.121         48        640: 100% ━━━━━━━━━━━━ 13/13 3.4s/it 43.8s2.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.2s
#                    all         43        200       0.83      0.171      0.358      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G      1.143      1.481        1.1         76        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.5s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.5s
#                    all         43        200       0.91      0.101      0.394      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G      1.197      1.419      1.107         72        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.1s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.6s
#                    all         43        200       0.76      0.315      0.414      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G      1.171      1.313      1.084         56        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.1s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.6s
#                    all         43        200      0.637      0.404      0.489      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G      1.208      1.376      1.116         67        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.0s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.4s
#                    all         43        200      0.666      0.435       0.56       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G      1.175      1.254      1.096         54        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.6s2.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.5s
#                    all         43        200      0.642      0.564      0.582      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G      1.197      1.299        1.1         34        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.8s2.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.5s
#                    all         43        200      0.504       0.54      0.488      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G      1.158      1.213      1.112         51        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.7s2.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.5s
#                    all         43        200      0.688      0.738      0.784      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100         0G       1.11       1.17      1.087         69        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.3s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.6s
#                    all         43        200      0.629      0.729      0.718      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100         0G      1.133      1.112      1.088         51        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.7s2.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.5s
#                    all         43        200      0.709       0.77      0.779      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100         0G       1.11      1.092      1.074         58        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.6s2.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.6s
#                    all         43        200      0.715      0.701      0.744      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         0G      1.081      1.017      1.047        116        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.8s2.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.9s6.7s
#                    all         43        200      0.762      0.736      0.759      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100         0G      1.149      1.094      1.091         39        640: 100% ━━━━━━━━━━━━ 13/13 3.2s/it 41.3s2.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.9s6.7s
#                    all         43        200      0.795       0.75      0.806      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100         0G      1.072      1.021       1.04         54        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.7s2.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.5s/it 2.9s6.8s
#                    all         43        200      0.726      0.729      0.749      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100         0G      1.061       1.05      1.055         42        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.5s2.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.6s
#                    all         43        200      0.744      0.829      0.807      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100         0G      1.066      1.005      1.055         55        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.8s2.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.5s/it 3.0s6.9s
#                    all         43        200      0.785       0.77      0.821      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100         0G      1.063      1.006      1.041         50        640: 100% ━━━━━━━━━━━━ 13/13 4.0s/it 52.0s3.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8s/it 3.6s8.4s
#                    all         43        200      0.709      0.835      0.782      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100         0G      1.061     0.9834       1.04         52        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.2s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.4s
#                    all         43        200      0.848      0.862      0.893      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100         0G      1.038      0.946      1.057         56        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.8s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.4s
#                    all         43        200      0.795      0.778       0.82      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100         0G      1.021      0.913      1.018         78        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.8s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.4s
#                    all         43        200      0.812      0.822      0.841      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100         0G      1.029     0.9014      1.009         71        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.5s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.4s
#                    all         43        200      0.833      0.845      0.882      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100         0G      1.005     0.9453       1.04         36        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.5s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.3s
#                    all         43        200      0.865      0.835      0.869      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100         0G     0.9915      0.878      1.012         61        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 40.1s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.8s6.3s
#                    all         43        200      0.717      0.813      0.791      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100         0G       1.04     0.8747      1.036         48        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.9s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3s/it 2.7s6.3s
#                    all         43        200      0.827      0.765      0.804      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100         0G      0.999     0.8793      1.024        100        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.8s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.2s
#                    all         43        200      0.808      0.821      0.858      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100         0G     0.9583     0.8499     0.9932         43        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.4s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.5s
#                    all         43        200      0.857       0.82      0.872      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100         0G     0.9631     0.8466     0.9934         36        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.8s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3s/it 2.7s6.2s
#                    all         43        200      0.842       0.79      0.848      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100         0G     0.9356     0.8112     0.9976         56        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.6s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3s/it 2.7s6.3s
#                    all         43        200       0.88       0.82      0.858       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100         0G     0.9502     0.8016     0.9983         78        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.9s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.4s
#                    all         43        200      0.869      0.863      0.876      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100         0G     0.9194     0.8093     0.9888         71        640: 100% ━━━━━━━━━━━━ 13/13 3.1s/it 39.7s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3s/it 2.7s6.3s
#                    all         43        200      0.893      0.836      0.876      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100         0G     0.9394      0.792      1.001         47        640: 100% ━━━━━━━━━━━━ 13/13 4.2s/it 54.8s3.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7s/it 3.4s7.8s
#                    all         43        200        0.8      0.865      0.859      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100         0G     0.9196     0.8307      0.999         56        640: 100% ━━━━━━━━━━━━ 13/13 4.1s/it 53.7s3.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7s/it 3.5s8.1s
#                    all         43        200      0.844      0.894      0.875      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100         0
0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100         0G     0.6377     0.4839     0.8685         27        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.1s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.3s
#                    all         43        200      0.857       0.91      0.909      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100         0G     0.6252     0.4812     0.8685         25        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.2s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3s/it 2.7s6.2s
#                    all         43        200      0.879       0.91      0.916      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100         0G     0.6085     0.4572     0.8586         18        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 38.8s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4s/it 2.7s6.3s
#                    all         43        200      0.891       0.89      0.917      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100         0G     0.6123     0.4739      0.866         40        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.5s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3s/it 2.7s6.3s
#                    all         43        200      0.886      0.895      0.916      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100         0G     0.6074     0.4591     0.8568         29        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.3s2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3s/it 2.7s6.2s
#                    all         43        200      0.874      0.901      0.915      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100         0G     0.6221     0.4565      0.869         29        640: 100% ━━━━━━━━━━━━ 13/13 3.0s/it 39.0s2.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3s/it 2.7s6.2s
#                    all         43        200       0.87      0.905      0.913      0.697
#
# 100 epochs completed in 1.251 hours.
# Optimizer stripped from D:\FPT_university\termno7\DAT301m\OCR\runs\detect\train\weights\last.pt, 5.5MB
# Optimizer stripped from D:\FPT_university\termno7\DAT301m\OCR\runs\detect\train\weights\best.pt, 5.5MB
#
# Validating D:\FPT_university\termno7\DAT301m\OCR\runs\detect\train\weights\best.pt...
# Ultralytics 8.3.250  Python-3.10.11 torch-2.9.1+cpu CPU (12th Gen Intel Core i5-12500H)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.1s/it 2.2s4.8s
#                    all         43        200      0.855      0.905       0.91      0.707
# Speed: 0.8ms preprocess, 47.7ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to D:\FPT_university\termno7\DAT301m\OCR\runs\detect\train

# %% [markdown]
# ## 8. Evaluation

# %%
from ultralytics import YOLO

model_path = "runs/detect/train/weights/best.pt"
model = YOLO(model_path)

metrics = model.val()
# Out:
# Ultralytics 8.3.250  Python-3.10.11 torch-2.9.1+cpu CPU (12th Gen Intel Core i5-12500H)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1015.3621.0 MB/s, size: 162.1 KB)
# val: Scanning D:\FPT_university\termno7\DAT301m\OCR\datasets\yolo_data\val\labels.cache... 43 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 43/43 43.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.4it/s 2.1s1.4s
#                    all         43        200      0.855      0.905       0.91      0.707
# Speed: 0.7ms preprocess, 41.5ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to D:\FPT_university\termno7\DAT301m\OCR\runs\detect\val

# %% [markdown]
# ## 9. Inference

# %%
import json

import cv2
import matplotlib.pyplot as plt


def visualize_bbox(
    img_path, predictions, conf_thres=0.8, font=cv2.FONT_HERSHEY_SIMPLEX
):
    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    for prediction in predictions:
        conf_score = prediction["confidence"]

        if conf_score < conf_thres:
            continue

        bbox = prediction["box"]
        xmin = int(bbox["x1"])
        ymin = int(bbox["y1"])
        xmax = int(bbox["x2"])
        ymax = int(bbox["y2"])

        cv2.rectangle(img, (xmin, ymin), (xmax, ymax), (0, 255, 0), 3)

        text = f"{conf_score:.2f}"
        (text_width, text_height), _ = cv2.getTextSize(text, font, 1, 2)

        cv2.rectangle(
            img,
            (xmin, ymin - text_height - 5),
            (xmin + text_width, ymin),
            (0, 255, 0),
            -1,
        )
        cv2.putText(img, text, (xmin, ymin - 5), font, 1, (0, 0, 0), 2)

    return img

# %%
from ultralytics import YOLO

model_path = "runs/detect/train/weights/best.pt"
img_path = "datasets/SceneTrialTrain/apanar_06.08.2002/IMG_1255.JPG"
conf_thres = 0.75
model = YOLO(model_path)

# Run inference
results = model(img_path, verbose=False)
predictions = json.loads(results[0].to_json())
visualized_img = visualize_bbox(img_path, predictions, conf_thres)

# %matplotlib inline
plt.imshow(visualized_img)
plt.axis("off")
plt.show()
